# %%
## import env variables
from config import init_env
from config import variables
import importlib
variables = importlib.reload(variables)
init_env.set_environment_variables()

# %% [markdown]
# ### Web url agent

# %%
from weburl_agent import WebURLDetailAgent
url="https://www.duh.de/presse/pressemitteilungen/pressemitteilung/hvo100-noch-schmutziger-als-herkoemmlicher-diesel-abgasmessungen-der-deutschen-umwelthilfe-zerstoeren/"
url="https://www.straitstimes.com/world/united-states/trump-says-not-concerned-by-chinese-drills-around-taiwan"

# %%
agentcn = WebURLDetailAgent()
result = agentcn.run(url)
print(result)
# Out:
# 立即注册：将ST的新闻通讯发送到您的收件箱
#
# 中国于12月29日启动了包括实弹演习在内的行动，以展示武力，此前美国宣布向台湾提供有史以来最大的一揽子武器。
#
# 照片：法新社
#
# 发表于2025年12月30日，上午07:02
#
# 更新于2025年12月30日，上午11:39
#
# 佛罗里达州棕榈滩——美国总统唐纳德·特朗普淡化了中国在台湾周围的最新动作，称其为长期军事演习的延续。
#
# 中国于12月29日启动了包括实弹演习在内的行动，以展示武力，此前美国宣布向台湾提供有史以来最大的一揽子武器。
#
# 包括实弹演习
#
# 当被问及中国在岛屿周围的行动时，特朗普先生反而吹捧他与中国国家主席习近平的关系，并将最新活动视为例行公事。
#
# “我与习近平主席关系很好，他没有告诉我任何关于此事的信息，”特朗普先生在与以色列总理本雅明·内塔尼亚胡的新闻发布会上告诉记者。
#
# “我当然看到了，但他没有告诉我任何关于此事的信息。我不相信他会这样做，”特朗普先生说，没有进一步详细说明。
#
# 中国视台湾为一个必须最终被其控制的分裂省份，必要时可以使用武力——这一立场台北坚决拒绝。
#
# 自台湾总统赖清德于2024年5月上任以来，北京加大了对这个拥有2300万人口的自治岛屿的军事压力。
#
# “他们在那个地区进行海军演习已经有20年了，”特朗普先生说。
#
# 特朗普先生吹捧他与习近平的良好关系，双方在10月达成贸易休战，此前一系列针锋相对的关税震动了全球市场。
#
# 尽管世界上两个最大经济体继续在出口和监管限制方面争论不休，但两位领导人已讨论了美国领导人4月对中国的访问。彭博社
#
# 美国领导人4月对中国的访问

# %%
agentjp = WebURLDetailAgent(default_target_language="Japanese")
result = agentjp.run(url)
print(result)
# Out:
# 今すぐ登録: STのニュースレターを受信箱に配信
#
# 中国は12月29日、台湾への過去最大級の武器供給を発表した米国に対抗し、実弾演習を含む力強い示威行動を開始したと発表した。
#
# 写真: AFP
#
# 2025年12月30日午前7時2分発行
#
# 2025年12月30日午前11時39分更新
#
# フロリダ州パームビーチ - 米国のドナルド・トランプ大統領は、中国の最新の台湾周辺の動きを軽視し、長年続いている軍事演習の延長と見なした。
#
# 中国は12月29日、台湾への過去最大級の武器供給を発表した米国に対抗し、実弾演習を含む力強い示威行動を開始したと発表した。
#
# 実弾演習を含む
#
# 台湾周辺の中国の行動について尋ねられた際、トランプ氏は中国の習近平国家主席との関係を誇示し、最新の活動を日常的なものと見なした。
#
# 「私は習主席と素晴らしい関係を築いており、彼から何も聞いていない」とトランプ氏はイスラエルのベンヤミン・ネタニヤフ首相と共に記者会見で語った。
#
# 「確かに見たことはあるが、彼から何も聞いていない。そして彼がそれを行うとは思わない」とトランプ氏はさらに詳しく説明せずに述べた。
#
# 中国は台湾を最終的に自らの支配下に置くべき離脱した省と見なしており、必要であれば武力でそうするという立場を取っているが、台北はこれを断固として拒否している。
#
# 台湾の頼清徳総統が2024年5月に就任して以来、北京は2300万人の自治島に対する軍事的圧力を強化している。
#
# 「彼らはその地域で20年間海軍演習を行っている」とトランプ氏は述べた。
#
# トランプ氏は、習氏との素晴らしい関係を誇示しており、相互の関税が世界市場を揺るがした後、10月に貿易緊張を緩和した。
#
# 両指導者は、世界最大の2つの経済が輸出と規制の制限をめぐって争い続ける中、米国指導者の4月の中国訪問について話し合った。ブルームバーグ
#
# 米国指導者の4月の中国訪問

# %%
imgurl="https://bmw.scene7.com/is/image/BMW/g26_bev_mp_positioning_image:16to7?fmt=webp&wid=2560&hei=1120" 
agenten = WebURLDetailAgent(default_target_language="English")
result = agenten.run(imgurl)
print(result)
# Out:
# The image depicts a silver BMW car driving on a road with a scenic backdrop. The car is shown from the front, highlighting its sleek design and distinctive grille. The headlights are illuminated, enhancing its dynamic look. The license plate reads "M IA 127E." The background features a rocky landscape with a blurred effect, suggesting motion, and a clear blue sky with some clouds. The scene conveys a sense of speed and elegance.
